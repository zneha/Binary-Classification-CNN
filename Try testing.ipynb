# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model
import time

start = time.time()

#Define Path
model_path = './models/model.h5'
model_weights_path = './models/weights.h5'
test_path = r"Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test"

#Load the pre-trained models
model = load_model(model_path)
model.load_weights(model_weights_path)

#Define image parameters
img_width, img_height = 16, 16

#Prediction Function
def predict(file):
  x = load_img(file, target_size=(img_width,img_height))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = model.predict(x)
  result = array[0]
  answer = np.argmax(result)
#   print("result",result)
#   print("answer",answer)
  if answer == 1:
    print("Predicted: Good")
  elif answer == 0:
    print("Predicted: Noisy")
#   elif answer == 2:
#     print("Predicted: soccer_ball")

  return answer

#Walk the directory for every image
for i, ret in enumerate(os.walk(test_path)):
  for i, filename in enumerate(ret[2]):
    if filename.startswith("."):
      continue
    
    print(ret[0] + '/' + filename)
    result = predict(ret[0] + '/' + filename)
    print(" ")

#Calculate execution time
end = time.time()
dur = end-start

if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11905.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11906.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11907.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11908.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11909.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11910.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11911.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11912.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11913.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11914.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11915.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11916.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_good_data11917.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10969.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10972.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10973.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10974.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10975.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10976.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10977.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10978.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10979.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10980.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10981.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10982.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10983.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10984.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10985.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10986.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10987.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10988.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10989.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10990.png
# Predicted: Noisy
#
# Z:\User Data\Neha reddy\ECG\Prelim AIM\Data\Machine Learning\CNN\try test/3012972_20120508_EDF_noisy_data10991.png
# Predicted: Noisy
#
# Execution Time: 0.8854742050170898 seconds
